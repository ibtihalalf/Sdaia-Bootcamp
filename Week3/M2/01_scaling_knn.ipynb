# %% [markdown]
# <a href="https://colab.research.google.com/github/ibtihalalf/Sdaia-Bootcamp/blob/main/Week3/M2/01_scaling_knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise: Effect of rescaling on a k-neighbors models

# %% [markdown]
# In this exercise, we will use the **PRIMM** (Predict, Run, Investigate, Modify, Make) method to understand the importance of preprocessing numerical data—specifically, how feature scaling impacts distance-based algorithms like K-Nearest Neighbors (KNN).

# %% [markdown]
# ### 1. Predict

# %% [markdown]
# Read the code in the "Run" section below, but **do not run it yet**.
#
# We are using the `KNeighborsClassifier` on two features from the Breast Cancer dataset: `mean area` and `mean smoothness`.
#
# - `mean area` has values that vary between approximately `143.5` and `2501.0`.
# - `mean smoothness` has values that vary between approximately `0.05` and `0.16`.
#
# We train a model on both the unscaled and scaled versions (using `StandardScaler`) of these two features.
#
# **Predict:**
#
# 1. Will the decision boundaries for the model trained on unscaled data and scaled data be the same or different?
# 2. For the unscaled data, distances will be dominated by which feature? Why?

# %% [markdown]
# 1 - no , The decision boundaries are different between the unscaled and scaled models.
#
# 2 - Mean texture will be dominated , because its have large scale compare with mean smoothness .

# %% [markdown]
# ### 2. Run

# %% [markdown]
# Run the following code block to visualize the decision boundary of the KNN classifier on the two versions of the data.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.neighbors import KNeighborsClassifier

# %%
# Load the dataset
cancer = load_breast_cancer(as_frame=True)
X, y = cancer.data, cancer.target

# %%
X
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
# Select a subset of features with different orders of magnitude
features = ["mean texture", "mean smoothness"]
X_plot = X[features]

# %%
# Scale the data and keep it as a DataFrame
scaler = StandardScaler()
X_plot_scaled = pd.DataFrame(
    scaler.fit_transform(X_plot),
    columns=X_plot.columns
)

# %%
# Create a KNN classifier
clf = KNeighborsClassifier(n_neighbors=20)

# %%
def fit_and_plot_model(X_data, y_data, clf, ax):
    clf.fit(X_data, y_data)
    disp = DecisionBoundaryDisplay.from_estimator(
        clf,
        X_data,
        response_method="predict",
        alpha=0.5,
        ax=ax,
    )
    disp.ax_.scatter(X_data[features[0]], X_data[features[1]], c=y_data, s=20, edgecolor="k")
    disp.ax_.set_xlim((X_data[features[0]].min(), X_data[features[0]].max()))
    disp.ax_.set_ylim((X_data[features[1]].min(), X_data[features[1]].max()))
    return disp.ax_

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

fit_and_plot_model(X_plot, y, clf, ax1)
ax1.set_title("KNN without scaling")

fit_and_plot_model(X_plot_scaled, y, clf, ax2)
ax2.set_xlabel(f"scaled {features[0]}")
ax2.set_ylabel(f"scaled {features[1]}")
_ = ax2.set_title("KNN with scaling")

plt.show()

# %% [markdown]
# ### 3. Investigate

# %% [markdown]
# Review the output.
#
# - Was your prediction correct?
# - How did scaling affect the decision boundaries?
# - Look at the scale of the x-axis and y-axis in both plots. Why does the plot on the left visually emphasize vertical decision boundaries (meaning decisions rely largely on the x-axis)?

# %% [markdown]
# 1 ) yes
#
# 2 ) Scaling significantly changed the decision boundaries:
#
# Without scaling:
#
# The boundaries are mostly straight and vertical, meaning the model relies heavily on one feature.
#
# With scaling:
#
# The boundaries become more complex and balanced, reflecting the influence of both features.
#
# 3 ) Because of the difference in feature scales:
#
# The x-axis (mean texture) has a much larger range (≈ 10 to 35)
#
# The y-axis (mean smoothness) has a very small range (≈ 0.06 to 0.16)
#
#  As a result:
#
# Changes in the x-axis dominate the distance calculation,The y-axis has very little influence
#
# So the model makes decisions mostly based on the x-axis → leading to vertical decision boundaries.

# %% [markdown]
# ### 4. Modify

# %% [markdown]
# Modify the code below to experiment with the algorithm:
#
# 1. Change the value of `n_neighbors` (e.g., to 1 or 50) and run the cell again. What changes do you observe in the boundary map?
# 2. Swap `StandardScaler` with `MinMaxScaler` (from `sklearn.preprocessing`). How does it change the scaled plot?

# %%
from sklearn.preprocessing import MinMaxScaler

# Scale the data and keep it as a DataFrame
scaler = MinMaxScaler()
X_plot_scaled = pd.DataFrame(
    scaler.fit_transform(X_plot),
    columns=X_plot.columns
)

# Create a KNN classifier
clf = KNeighborsClassifier(n_neighbors=40)

def fit_and_plot_model(X_data, y_data, clf, ax):
    clf.fit(X_data, y_data)
    disp = DecisionBoundaryDisplay.from_estimator(
        clf,
        X_data,
        response_method="predict",
        alpha=0.5,
        ax=ax,
    )
    disp.ax_.scatter(X_data[features[0]], X_data[features[1]], c=y_data, s=20, edgecolor="k")
    disp.ax_.set_xlim((X_data[features[0]].min(), X_data[features[0]].max()))
    disp.ax_.set_ylim((X_data[features[1]].min(), X_data[features[1]].max()))
    return disp.ax_

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

fit_and_plot_model(X_plot, y, clf, ax1)
ax1.set_title("KNN without scaling")

fit_and_plot_model(X_plot_scaled, y, clf, ax2)
ax2.set_xlabel(f"scaled {features[0]}")
ax2.set_ylabel(f"scaled {features[1]}")
_ = ax2.set_title("KNN with scaling")

plt.show()

# %% [markdown]
# 1 - Increasing n_neighbors from 20 to 40 made the KNN boundary smoother and more generalized.
#
# 2 - Scaling still has the biggest effect: without scaling, the model relies mostly on mean texture; with scaling, it uses both features more fairly. When using MinMaxScaler, features are scaled to the range [0, 1], which ensures both features contribute equally to distance calculations and leads to more balanced decision boundaries.

# %% [markdown]
# ### 5. Make

# %% [markdown]
# Now it's your turn. Use the same dataset but select two completely different features, like `mean radius` and `mean texture`.
#
# - Print their minimum and maximum values to evaluate their magnitude differences.
# - Apply `KNeighborsClassifier` WITHOUT scaling and plot the decision boundary.
# - Apply `KNeighborsClassifier` WITH scaling and plot the decision boundary.
# - Does scaling make as huge of an impact here? Why or why not?

# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.neighbors import KNeighborsClassifier

# %%
df = load_breast_cancer(as_frame=True)
X ,y = df.data , df.target
X
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
features = ["mean radius" ,"mean texture"]
X = X[features]
print(X.agg(["min", "max"]))
# Out:
#      mean radius  mean texture
# min        6.981          9.71
# max       28.110         39.28

# %%
scalar = StandardScaler()
X_scaled = pd.DataFrame(
    scalar.fit_transform(X),
    columns = X.columns
)

# %%
clf = KNeighborsClassifier(n_neighbors = 40)

# %%
def fit_and_plot_model(X_data , y_data , clf , ax):
  clf.fit(X_data , y_data)
  disp = DecisionBoundaryDisplay.from_estimator(
      clf,
      X_data,
      response_method="predict",
      alpha = 0.5,
      ax=ax
  )

  disp.ax_.scatter(X_data[features[0]], X_data[features[1]], c=y_data, s=40, edgecolor="k")
  disp.ax_.set_xlim((X_data[features[0]].min(), X_data[features[0]].max()))
  disp.ax_.set_ylim((X_data[features[1]].min(), X_data[features[1]].max()))
  return disp.ax_

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

fit_and_plot_model(X, y, clf, ax1)
ax1.set_title("KNN without scaling")

fit_and_plot_model(X_scaled, y, clf, ax2)
ax2.set_xlabel(f"scaled {features[0]}")
ax2.set_ylabel(f"scaled {features[1]}")
_ = ax2.set_title("KNN with scaling")

plt.show()

# %% [markdown]
# No, scaling does not make as huge of an impact in this case.
#
# Because the two selected features (mean radius and mean texture) already have similar value ranges (magnitudes):
